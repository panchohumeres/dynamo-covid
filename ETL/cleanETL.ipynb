# %%
import os
from pathlib import Path
import pandas as pd
import sys

# %%
sys.path.append('..')

# %%
mkdir ../CRONTAB/logs

# %%
logspath='../CRONTAB/logs'

# %%
cachepath='../ETLcache'

# %%
def paths_to_df(root):
    paths=sorted(Path(root).iterdir(), key=os.path.getmtime)
    paths_str=[]
    size=[]
    for p in paths:
        paths_str.append(str(p))
        size.append(p.stat().st_size)
    paths=pd.DataFrame({'paths':paths_str,'sizeB':size})
    paths['sizeMB']=paths.sizeB/1000000
    paths['sizeCUMSUM']=paths['sizeMB'].cumsum()
    
    return paths

# %%
def remove_files(paths,MBthreshold=200):
    for p in paths.loc[paths['sizeCUMSUM']>MBthreshold,'paths'].to_list():
        print('deleting file: '+p)
        os.remove(p)

# %%
logspaths=paths_to_df(logspath)

# %%
logspaths
# Out:
# Empty DataFrame
# Columns: [paths, sizeB, sizeMB, sizeCUMSUM]
# Index: []

# %%
remove_files(logspaths,MBthreshold=10)

# %%
logspaths=paths_to_df(logspath)

# %%
logspaths
# Out:
# Empty DataFrame
# Columns: [paths, sizeB, sizeMB, sizeCUMSUM]
# Index: []

# %%
cachepaths=paths_to_df(cachepath)

# %%
cachepaths
# Out:
#                                                   paths    sizeB    sizeMB  \
# 0     ../ETLcache/producto1_Covid_19_01122020_011540...   163245  0.163245
# 1     ../ETLcache/producto1_Covid_19_T_01122020_0115...   153669  0.153669
# 2     ../ETLcache/producto1_Covid_19_std_01122020_01...  1972025  1.972025
# 3     ../ETLcache/producto10_FallecidosEtario_011220...     9556  0.009556
# 4     ../ETLcache/producto10_FallecidosEtario_T_0112...     8016  0.008016
# ...                                                 ...      ...       ...
# 1963                       ../ETLcache/cuarentenas.xlsx   123679  0.123679
# 1964                  ../ETLcache/paso_a_paso_2021.xlsx    47547  0.047547
# 1965                  ../ETLcache/paso_a_paso_2020.xlsx   142177  0.142177
# 1966                      ../ETLcache/Muertes_DEIS.html  3508849  3.508849
# 1967                  ../ETLcache/Contagios_ICOVID.html  3511980  3.511980
#
#        sizeCUMSUM
# 0        0.163245
# 1        0.316914
# 2        2.288939
# 3        2.298495
# 4        2.306511
# ...           ...
# 1963  3952.848699
# 1964  3952.896246
# 1965  3953.038423
# 1966  3956.547272
# 1967  3960.059252
#
# [1968 rows x 4 columns]

# %%
remove_files(cachepaths,MBthreshold=500)
# Out:
# deleting file: ../ETLcache/producto45_CasosConfirmadosPorComunaHistorico_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosConfirmadosPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosConfirmadosPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosNoNotificadosPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosNoNotificadosPorComunaHistorico_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosNoNotificadosPorComunaHistorico_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosNoNotificadosPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosNoNotificadosPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosProbablesPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosProbablesPorComunaHistorico_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosProbablesPorComunaHistorico_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosProbablesPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto45_CasosProbablesPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto45_SemanasEpidemiologica_01122020_011540.csv
# deleting file: ../ETLcache/producto46_activos_vs_recuperado_01122020_011540.csv
# deleting file: ../ETLcache/producto46_activos_vs_recuperados_std_01122020_011540.csv
# deleting file: ../ETLcache/producto46_activos_vs_recuperados_t_01122020_011540.csv
# deleting file: ../ETLcache/producto47_MediaMovil_01122020_011540.csv
# deleting file: ../ETLcache/producto47_MediaMovil_T_01122020_011540.csv
# deleting file: ../ETLcache/producto47_MediaMovil_std_01122020_011540.csv
# deleting file: ../ETLcache/producto48_SOCHIMI_01122020_011540.csv
# deleting file: ../ETLcache/producto48_SOCHIMI_T_01122020_011540.csv
# deleting file: ../ETLcache/producto48_SOCHIMI_std_01122020_011540.csv
# deleting file: ../ETLcache/producto49_Positividad_Diaria_Media_01122020_011540.csv
# deleting file: ../ETLcache/producto49_Positividad_Diaria_Media_T_01122020_011540.csv
# deleting file: ../ETLcache/producto49_Positividad_Diaria_Media_std_01122020_011540.csv
# deleting file: ../ETLcache/producto5_TotalesNacionale_01122020_011540.csv
# deleting file: ../ETLcache/producto5_TotalesNacionales_T_01122020_011540.csv
# deleting file: ../ETLcache/producto5_TotalesNacionales_std_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEISPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEISPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEISPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_confirmadosPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_confirmadosPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_confirmadosPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_sospechososPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_sospechososPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto50_DefuncionesDEIS_sospechososPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto51_ISCI_std_01122020_011540.csv
# deleting file: ../ETLcache/producto52_Camas_UCI_01122020_011540.csv
# deleting file: ../ETLcache/producto52_Camas_UCI_std_01122020_011540.csv
# deleting file: ../ETLcache/producto52_Camas_UCI_t_01122020_011540.csv
# deleting file: ../ETLcache/producto53_confirmados_nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto53_confirmados_provinciale_01122020_011540.csv
# deleting file: ../ETLcache/producto53_confirmados_regionale_01122020_011540.csv
# deleting file: ../ETLcache/producto53_confirmados__01122020_011540.csv
# deleting file: ../ETLcache/producto54_r.nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto54_r.provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto54_r.regional_01122020_011540.csv
# deleting file: ../ETLcache/producto54_r_01122020_011540.csv
# deleting file: ../ETLcache/producto55_Positividad_nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto55_Positividad_por_comuna_01122020_011540.csv
# deleting file: ../ETLcache/producto55_Positividad_por_provincia_01122020_011540.csv
# deleting file: ../ETLcache/producto55_Positividad_por_region_01122020_011540.csv
# deleting file: ../ETLcache/producto56_prob48.nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto56_prob48.provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto56_prob48.regional_01122020_011540.csv
# deleting file: ../ETLcache/producto57_fallecidos_hospitalizado_01122020_011540.csv
# deleting file: ../ETLcache/producto57_fallecidos_hospitalizados_std_01122020_011540.csv
# deleting file: ../ETLcache/producto58_Camas_UCI_diaria_01122020_011540.csv
# deleting file: ../ETLcache/producto58_Camas_UCI_diarias_std_01122020_011540.csv
# deleting file: ../ETLcache/producto58_Camas_UCI_diarias_t_01122020_011540.csv
# deleting file: ../ETLcache/producto59_etapa_clinica_por_fecha_notificacion_01122020_011540.csv
# deleting file: ../ETLcache/producto60_etapa_clinica_por_fi_01122020_011540.csv
# deleting file: ../ETLcache/producto61_serie_fallecidos_comuna_01122020_011540.csv
# deleting file: ../ETLcache/producto62_casos_nuevos_acumulados_por_fecha_01122020_011540.csv
# deleting file: ../ETLcache/producto63_NNotificacionPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto63_NNotificacionPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto63_NNotificacionPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto64_BACPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto64_BACPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto64_BACPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto65_PositividadPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto65_PositividadPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto65_PositividadPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto66_CoberturaPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto66_CoberturaPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto66_CoberturaPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto67_OportunidadPorComuna_01122020_011540.csv
# deleting file: ../ETLcache/producto67_OportunidadPorComuna_T_01122020_011540.csv
# deleting file: ../ETLcache/producto67_OportunidadPorComuna_std_01122020_011540.csv
# deleting file: ../ETLcache/producto68_tasa_test_semanal_comunal_01122020_011540.csv
# deleting file: ../ETLcache/producto68_tasa_test_semanal_nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto68_tasa_test_semanal_provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto68_tasa_test_semanal_regional_01122020_011540.csv
# deleting file: ../ETLcache/producto69_carga.nacional.ajustada_01122020_011540.csv
# deleting file: ../ETLcache/producto69_carga.provincial.ajustada_01122020_011540.csv
# deleting file: ../ETLcache/producto69_carga.regional.ajustada_01122020_011540.csv
# deleting file: ../ETLcache/producto69_carga.ss.ajustada_01122020_011540.csv
# deleting file: ../ETLcache/producto7_PCR_01122020_011540.csv
# deleting file: ../ETLcache/producto7_PCR_T_01122020_011540.csv
# deleting file: ../ETLcache/producto7_PCR_std_01122020_011540.csv
# deleting file: ../ETLcache/producto70_total72.nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto70_total72.provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto70_total72.regional_01122020_011540.csv
# deleting file: ../ETLcache/producto71_not48.nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto71_not48.provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto71_not48.regional_01122020_011540.csv
# deleting file: ../ETLcache/producto72_lab24.nacional_01122020_011540.csv
# deleting file: ../ETLcache/producto72_lab24.provincial_01122020_011540.csv
# deleting file: ../ETLcache/producto72_lab24.regional_01122020_011540.csv
# deleting file: ../ETLcache/producto8_UCI_01122020_011540.csv
# deleting file: ../ETLcache/producto8_UCI_T_01122020_011540.csv
# deleting file: ../ETLcache/producto8_UCI_std_01122020_011540.csv
# deleting file: ../ETLcache/producto9_HospitalizadosUCIEtario_01122020_011540.csv
# deleting file: ../ETLcache/producto9_HospitalizadosUCIEtario_T_01122020_011540.csv
# deleting file: ../ETLcache/producto9_HospitalizadosUCIEtario_std_01122020_011540.csv
# deleting file: ../ETLcache/contagios_comunal@ivanMSC_02122020_002915.csv
# deleting file: ../ETLcache/info_comunal@ivanMSC_02122020_002915.csv
# deleting file: ../ETLcache/Muertes_DEIS_06122020_224126.png
# deleting file: ../ETLcache/Muertes_SOCHIMI_06122020_224126.png
# deleting file: ../ETLcache/Muertes_ConfirmadosPCR+_06122020_224126.png
# deleting file: ../ETLcache/muertes@perez_06122020_224126.csv
# deleting file: ../ETLcache/nacional@perez_06122020_224126.csv
# deleting file: ../ETLcache/DEIS_06122020_235946
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-35-d4c10d24b2a2> in <module>
# ----> 1 remove_files(cachepaths,MBthreshold=500)
#
# <ipython-input-27-86bf578c1a9a> in remove_files(paths, MBthreshold)
#       2     for p in paths.loc[paths['sizeCUMSUM']>MBthreshold,'paths'].to_list():
#       3         print('deleting file: '+p)
# ----> 4         os.remove(p)
#
# IsADirectoryError: [Errno 21] Is a directory: '../ETLcache/DEIS_06122020_235946'

# %%
cachepaths=paths_to_df(cachepath)

# %%
cachepaths
# Out:
#                                                   paths    sizeB    sizeMB  \
# 0     ../ETLcache/producto1_Covid_19_01122020_011540...   163245  0.163245
# 1     ../ETLcache/producto1_Covid_19_T_01122020_0115...   153669  0.153669
# 2     ../ETLcache/producto1_Covid_19_std_01122020_01...  1972025  1.972025
# 3     ../ETLcache/producto10_FallecidosEtario_011220...     9556  0.009556
# 4     ../ETLcache/producto10_FallecidosEtario_T_0112...     8016  0.008016
# ...                                                 ...      ...       ...
# 1849                       ../ETLcache/cuarentenas.xlsx   123679  0.123679
# 1850                  ../ETLcache/paso_a_paso_2021.xlsx    47547  0.047547
# 1851                  ../ETLcache/paso_a_paso_2020.xlsx   142177  0.142177
# 1852                      ../ETLcache/Muertes_DEIS.html  3508849  3.508849
# 1853                  ../ETLcache/Contagios_ICOVID.html  3511980  3.511980
#
#        sizeCUMSUM
# 0        0.163245
# 1        0.316914
# 2        2.288939
# 3        2.298495
# 4        2.306511
# ...           ...
# 1849  3687.124024
# 1850  3687.171571
# 1851  3687.313748
# 1852  3690.822597
# 1853  3694.334577
#
# [1854 rows x 4 columns]

# %%
os.system('jupyter nbconvert --output /home/jovyan/work/ETLdocs/' + 'ETL_cleanETL.html' + ' --to html ' + 
          '/home/jovyan/work/ETL/cleanETL.ipynb')
# Out:
# 0
